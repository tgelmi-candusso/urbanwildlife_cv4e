# %%
from torchvision.transforms import Compose, Resize, GaussianBlur, ToTensor, RandomRotation, RandomGrayscale, Normalize, Grayscale, RandomCrop, RandomApply
from PIL import Image
import os

directory ='/datadrive/animals_training_dataset/crops/fox/'
files_inside_s = os.listdir(directory)
#random.shuffle(files_inside_s)
files_inside_s = files_inside_s[100:150]
print(files_inside_s)
# Out:
# ['TUW11.04040094.JPG', 'TUW18.10090224.JPG', 'TUW11.04040095.JPG', 'TUW19.01080011.JPG', 'TUW11.04040096.JPG', 'TUW19.02010042.JPG', 'TUW11.05290676.JPG', 'TUW19.02010043.JPG', 'TUW11.05290677.JPG', 'TUW21.10130205 (2).JPG', 'TUW19.09270956.JPG', 'TUW19.10040268.JPG', 'TUW19.10040269.JPG', 'TUW19.10040270.JPG', 'TUW19.10100267.JPG', 'TUW19.10310577.JPG', 'TUW19.10310578.JPG', 'TUW19.10310579.JPG', 'TUW19.12170196.JPG', 'TUW19.12170197.JPG', 'TUW19.12170198.JPG', 'TUW19.12170199.JPG', 'TUW19.12170200.JPG', 'TUW19.12170201.JPG', 'TUW19.12210331.JPG', 'TUW2.09300427.JPG', 'TUW2.09300428.JPG', 'TUW2.09300429.JPG', 'TUW20.01020341.JPG', 'TUW20.01040001.JPG', 'TUW20.01070759.JPG', 'TUW20.01110962.JPG', 'TUW20.01200214.JPG', 'TUW21.01080284.JPG', 'TUW21.01130456.JPG', 'TUW21.01170310.JPG', 'TUW21.01200726.JPG', 'TUW21.01290254.JPG', 'TUW21.01290281.JPG', 'TUW21.01300291.JPG', 'TUW21.02050292.JPG', 'TUW21.02090140.JPG', 'TUW21.02120638.JPG', 'TUW21.02130648.JPG', 'TUW21.02240772.JPG', 'TUW21
# ...

# %%
y = 10
img = Image.open(os.path.join('/datadrive/animals_training_dataset/crops/fox/', files_inside_s[1])).convert("RGB")
img
# Out:
# <PIL.Image.Image image mode=RGB size=294x172>

# %%
import numpy as np
import matplotlib.pyplot as plt


img_np = np.array(img)
 
# plot the pixel values
plt.hist(img_np.ravel(), bins=50, density=True)
plt.xlabel("pixel values")
plt.ylabel("relative frequency")
plt.title("distribution of pixels")
# Out:
# Text(0.5, 1.0, 'distribution of pixels')

# %%
Resize((224,224))(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
GaussianBlur(kernel_size=(51),sigma=(0.05, 2))(img)
# Out:
# <PIL.Image.Image image mode=RGB size=294x172>

# %%
RandomRotation(degrees=(-45, 45))(img)
# Out:
# <PIL.Image.Image image mode=RGB size=294x172>

# %%
RandomGrayscale(20)(img)
# Out:
# <PIL.Image.Image image mode=RGB size=294x172>

# %%
RandomCrop(size=(img.height,50))(img)
# Out:
# <PIL.Image.Image image mode=RGB size=50x172>

# %%
img2 = ToTensor()(img)

# %%
img3 = Normalize(mean=(0.3725, 0.3725, 0.3725), std=(0.2030, 0.2030, 0.2030))(img2)
img3 = Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))(img2)

# %%
import torch

img4 = Normalize(torch.mean(img2, dim = (0, 1, 2)), torch.std(img2, dim = (0, 1, 2)))(img2)

# %%
img_np = np.array(img3)
 
# plot the pixel values
plt.hist(img_np.ravel(), bins=50, density=True)
plt.xlabel("pixel values")
plt.ylabel("relative frequency")
plt.title("distribution of pixels")
# Out:
# Text(0.5, 1.0, 'distribution of pixels')

# %%
img_np = np.array(img4)
 
# plot the pixel values
plt.hist(img_np.ravel(), bins=50, density=True)
plt.xlabel("pixel values")
plt.ylabel("relative frequency")
plt.title("distribution of pixels")
# Out:
# Text(0.5, 1.0, 'distribution of pixels')

# %%
mean_list = []
std_list = []

for i in files_inside_s:
    img = Image.open(os.path.join('/datadrive/animals_training_dataset/crops/fox/', str(i))).convert("RGB")
    img = Resize((224,224))(img)
    img = GaussianBlur(kernel_size=(51),sigma=(0.05, 2))(img)
    img =RandomRotation(degrees=(-45, 45))(img)
    img = RandomGrayscale(20)(img)
    #img = RandomApply(transforms = [RandomCrop(224, 50)], p=0.15)
    img = ToTensor()(img)
    mean, std = img.mean([1,2]), img.std([1,2])
    print("mean and std before normalize:")
    print("Mean of the image:", mean)
    print("Std of the image:", std)
# Out:
# Bad pipe message: %s [b'`\x99\x0e5\x85\xc3\xc0X\xda0\xfeP^\xa6\x15\x89 \x1c \xaa\xef\xa0rq\x85\xa3\xb6_\x89Hi\xf7v\x8do\xdeQ\x97eI\x9cr\xde\xa4\x94P_\xa0\x16\x0f\xa7\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'j\xc5L\x96\x8d\xf3\xd1\xca )\xf0a\x1e\x06R\x07 \x8ah\xa3\xb7^\x8e\x8b\xd4Qq\xc3\xb8Y\xbd\x81\x12\x0b\xa9y\xb4\x8c\x82\xd7\xb76\xfed\x90\xbf\x96\xf9{\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 u\x81\xfe\xf6\xfd\x94\xc0\xdb\x8eI\x0f\xa4Os\xb4\xa4\xf6z13\x05]\x18\xfc']
# ...
